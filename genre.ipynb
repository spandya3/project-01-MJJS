# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
movie_data = pd.read_csv("clean_movie_data.csv")
movie_data_df = pd.DataFrame(movie_data)

# %%
movie_data_df.head()
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                          Unfrosted  2023.0       PG-13            97.0
# 3                       The Fall Guy  2023.0       PG-13           126.0
# 4                        Challengers  2023.0           R           131.0
#
#                         Genre  Rating  Metascore           Director  \
# 0      Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# ...

# %%
# Step 1: Split the 'Genre' column by ', ' and expand the genres into separate rows
movie_data_df['Genre'] = movie_data_df['Genre'].str.split(', ')
# exploded_genres = movie_data_df.explode('Genre')

# # Step 2: Get unique genres
# unique_genres = exploded_genres['Genre'].unique()

# # Display the unique genres
# print("\nUnique Genres:")
# print(unique_genres)

movie_data_df['Genre'].dtypes()

# %%
# # Step 2: Get unique genres
# unique_genres = exploded_genres['Genre'].unique()

# # Display the unique genres
# print("\nUnique Genres:")
# print(unique_genres)

# %%
unique_genres_df = pd.DataFrame(unique_genres)
unique_genres_df
# Out:
#               0
# 0        Comedy
# 1         Drama
# 2       Romance
# 3        Action
# 4     Adventure
# 5        Sci-Fi
# 6     Biography
# 7       History
# 8         Sport
# 9        Horror
# 10     Thriller
# 11          War
# 12      Fantasy
# 13        Crime
# 14      Mystery
# 15        Music
# 16    Animation
# 17       Family
# 18      Musical
# 19      Western
# 20  Documentary
# 21    Film-Noir

# %%
movie_data_df['Genre'] = movie_data_df['Genre'].astype('|S', errors='ignore')
movie_data_df.head()
# col_genre_df = movie_data_df['Genre'].str.split(',', expand=True)
# col_genre_df
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                          Unfrosted  2023.0       PG-13            97.0
# 3                       The Fall Guy  2023.0       PG-13           126.0
# 4                        Challengers  2023.0           R           131.0
#
#                           Genre  Rating  Metascore           Director  \
# 0      [Comedy, Drama, Romance]     6.4       67.0  Michael Showalter
# ...
